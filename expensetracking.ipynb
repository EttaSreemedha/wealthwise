# %%
{
    "knowledge_base": [
        {
            "id": 1,
            "title": "10 Ways to Save on Rent in Expensive Cities",
            "category": "Accommodation",
            "tags": [
                "Rent",
                "Negotiation",
                "Shared Accommodation"
            ],
            "summary": "Tips on negotiating rent, looking for rental discounts, and finding shared accommodation options.",
            "key_points": [
                "Negotiate rent with landlords.",
                "Look for rental discounts during off-seasons.",
                "Consider shared accommodation to split costs.",
                "Get a roommate.",
                "Negotiate your lease.",
                "Consider moving to a cheaper neighborhood.",
                "Rent out extra rooms for short-term rentals.",
                "Opt for private rentals instead of corporate options.",
                "Negotiate rent during lease renewal.",
                "Sign extended leases for stability.",
                "Consider moving to affordable cities.",
                "Look for apartments in winter.",
                "Pay upfront for potential discounts."
            ]
        },
        {
            "id": 2,
            "title": "The Ultimate Guide to Choosing Affordable Neighborhoods",
            "category": "Accommodation",
            "tags": [
                "Neighborhoods",
                "Commute Costs",
                "Amenities"
            ],
            "summary": "How to research less expensive areas with good amenities and tips for reducing commute costs.",
            "key_points": [
                "Research neighborhoods with lower rent but good amenities.",
                "Evaluate commute costs when selecting a neighborhood."
            ]
        },
        {
            "id": 3,
            "title": "Negotiate Your Lease: How to Ask for Rent Reductions and Perks",
            "category": "Accommodation",
            "tags": [
                "Lease Negotiation",
                "Rent Reductions",
                "Perks"
            ],
            "summary": "A guide on effective negotiation strategies with landlords and what concessions to ask for.",
            "key_points": [
                "Ask for reduced rent or additional perks like free parking.",
                "Be prepared with market research to support your requests."
            ]
        },
        {
            "id": 4,
            "title": "Living with Roommates: Pros, Cons, and Cost Benefits",
            "category": "Accommodation",
            "tags": [
                "Roommates",
                "Cost Sharing",
                "Utilities"
            ],
            "summary": "Covers how shared living can cut costs, reduce utility bills, and improve overall affordability.",
            "key_points": [
                "Sharing rent and utilities lowers overall costs.",
                "Discuss responsibilities upfront to avoid conflicts."
            ]
        },
        {
            "id": 5,
            "title": "Bulk Buying: How to Save Money and Reduce Waste",
            "category": "Groceries",
            "tags": [
                "Bulk Buying",
                "Cost Saving",
                "Non-Perishables"
            ],
            "summary": "Tips on buying non-perishable items in bulk and storing them to avoid spoilage.",
            "key_points": [
                "Purchase non-perishables in bulk for discounts.",
                "Store items properly to reduce waste.",
                "Plan meals to reduce waste.",
                "Use grocery apps for discounts."
            ]
        },
        {
            "id": 6,
            "title": "The Smart Shopper’s Guide to Using Coupons and Cashback Apps",
            "category": "Groceries",
            "tags": [
                "Coupons",
                "Cashback Apps",
                "Savings"
            ],
            "summary": "A comprehensive list of popular grocery discount and cashback apps, with tips on maximizing their benefits.",
            "key_points": [
                "Use cashback apps to earn rewards.",
                "Combine coupons with store discounts for maximum savings.",
                "Wait for seasonal sales.",
                "Make a shopping list to avoid impulse buys."
            ]
        },
        {
            "id": 7,
            "title": "Meal Planning and Prep to Cut Grocery Bills in Half",
            "category": "Groceries",
            "tags": [
                "Meal Planning",
                "Cost Saving",
                "Bulk Preparation"
            ],
            "summary": "Discusses how weekly meal planning and bulk meal preparation can significantly reduce food expenses.",
            "key_points": [
                "Plan meals weekly to avoid unnecessary purchases.",
                "Prepare meals in bulk to save time and money."
            ]
        },
        {
            "id": 8,
            "title": "Avoiding Food Waste: Simple Tips to Keep Your Food Fresh",
            "category": "Groceries",
            "tags": [
                "Food Waste",
                "Storage Tips",
                "Freshness"
            ],
            "summary": "A guide to storing produce properly and managing leftovers to reduce the amount of spoiled food.",
            "key_points": [
                "Store produce in appropriate conditions to maximize freshness.",
                "Use leftovers creatively to minimize waste.",
                "Tips on buying non-perishable items in bulk and storing them properly to avoid spoilage"
            ]
        },
        {
            "id": 9,
            "title": "Save Money on Commutes: Public Transport vs. Carpooling",
            "category": "Transport",
            "tags": [
                "Commutes",
                "Public Transport",
                "Carpooling"
            ],
            "summary": "A comparison of costs between car ownership, carpooling, and public transport with tips on choosing the best option.",
            "key_points": [
                "Opt for public transport to save money.",
                "Carpooling can significantly reduce fuel costs."
            ]
        },
        {
            "id": 10,
            "title": "Fuel-Efficient Driving Tips That Save Gas Money",
            "category": "Transport",
            "tags": [
                "Fuel Efficiency",
                "Driving Tips",
                "Savings"
            ],
            "summary": "Advice on driving techniques to improve fuel efficiency and reduce costs at the pump.",
            "key_points": [
                "Maintain a steady speed to improve fuel efficiency.",
                "Keep your car well-maintained to save on fuel costs.",
                "Turn off your engine when you’re stopped for more than 60 seconds, except in traffic.",
                "Walk or bike to your destination for health and cost savings.",
                "Use a fuel consumption display to monitor usage.",
                "Check and maintain proper tire pressure.",
                "Avoid high speeds to conserve fuel.",
                "Try carpooling or public transport to save money.",
                "Consider a more fuel-efficient vehicle."
            ]
        },
        {
            "id": 11,
            "title": "Cycling as an Affordable and Healthy Commute Option",
            "category": "Transport",
            "tags": [
                "Cycling",
                "Commutes",
                "Health"
            ],
            "summary": "Benefits of cycling to work or school, with cost comparisons and beginner tips for starting.",
            "key_points": [
                "Cycling is a low-cost, eco-friendly commute option.",
                "Invest in safety gear for a secure ride."
            ]
        },
        {
            "id": 12,
            "title": "10 Energy-Saving Tips for Lower Utility Bills",
            "category": "Utilities",
            "tags": [
                "Energy Saving",
                "Lower Bills",
                "Appliances"
            ],
            "summary": "Simple changes to reduce electricity consumption, like using LED bulbs, smart thermostats, and energy-efficient appliances.",
            "key_points": [
                "Switch to LED bulbs for lower energy consumption.",
                "Unplug appliances when not in use to save energy.",
                "Wash and dry clothes efficiently.",
                "Insulate your roof.",
                "Plan meals to reduce energy usage during cooking.",
                "Switch off electronics when not in use."
            ]
        },
        {
            "id": 13,
            "title": "Finding Free Events and Activities in Your City",
            "category": "Entertainment",
            "tags": [
                "Free Events",
                "Activities",
                "City Guide"
            ],
            "summary": "Tips on locating free local events, such as concerts, exhibitions, and outdoor activities.",
            "key_points": [
                "Check community boards for free local events.",
                "Explore outdoor activities for affordable entertainment.",
                "Consider streaming services over cable."
            ]
        },
        {
            "id": 14,
            "title": "Finding Scholarships and Grants for School-Age Children",
            "category": "Kids Schooling",
            "tags": [
                "Scholarships",
                "Grants",
                "Education"
            ],
            "summary": "Information on where to find scholarships and how to apply for educational grants.",
            "key_points": [
                "Research scholarship opportunities online.",
                "Reach out to local organizations for grant information.",
                "Look for second-hand books.",
                "look for places where you can find affordable, gently-used textbooks and school materials.",
                "explore online resources, educational games, and library programs that provide quality learning experiences for free or at a low cost"
            ]
        },
        {
            "id": 15,
            "title": "How to Save Money on Food at Restaurants and the Grocery Store",
            "category": "Financial Literacy",
            "tags": [
                "Budgeting",
                "Food Savings",
                "Grocery Shopping"
            ],
            "summary": "Tips to save money on food at restaurants and grocery stores.",
            "key_points": [
                "Order water at restaurants to avoid overpriced drinks.",
                "Develop a weekly food plan to minimize waste.",
                "Buy staple items like rice, pasta, and canned goods for less than $2.",
                "Combine coupons with discounts for savings.",
                "Shop at farmer’s markets for fresh produce."
            ]
        }
    ]
}
# Out:
# {'knowledge_base': [{'id': 1,
#    'title': '10 Ways to Save on Rent in Expensive Cities',
#    'category': 'Accommodation',
#    'tags': ['Rent', 'Negotiation', 'Shared Accommodation'],
#    'summary': 'Tips on negotiating rent, looking for rental discounts, and finding shared accommodation options.',
#    'key_points': ['Negotiate rent with landlords.',
#     'Look for rental discounts during off-seasons.',
#     'Consider shared accommodation to split costs.',
#     'Get a roommate.',
#     'Negotiate your lease.',
#     'Consider moving to a cheaper neighborhood.',
#     'Rent out extra rooms for short-term rentals.',
#     'Opt for private rentals instead of corporate options.',
#     'Negotiate rent during lease renewal.',
#     'Sign extended leases for stability.',
#     'Consider moving to affordable cities.',
#     'Look for apartments in winter.',
#     'Pay upfront for potential discounts.']},
#   {'id': 2,
# ...

# %%
pip install faiss-cpu sentence-transformers transformers huggingface_hub
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 12.8 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install transformers sentence-transformers faiss-cpu
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sentence_transformers import SentenceTransformer
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer
from huggingface_hub import login
import faiss
import numpy as np

# Authenticate with Hugging Face
login(token="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")

# Load LLaMA 2 Model
model_name = "meta-llama/Llama-2-7b-chat-hf"
tokenizer = AutoTokenizer.from_pretrained(model_name)
llama_model = AutoModelForCausalLM.from_pretrained(model_name)
llama_pipe = pipeline("text-generation", model=llama_model, tokenizer=tokenizer)


   

# Embed Knowledge Base
embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
texts = [
    f"{item['category']} {item['summary']} {' '.join(item['key_points'])}"
    for item in knowledge_base
]
embeddings = np.array(embedding_model.encode(texts))

# Build FAISS Index
dimension = embeddings.shape[1]
faiss_index = faiss.IndexFlatL2(dimension)
faiss_index.add(embeddings)

# Define Retrieval Function
def retrieve_suggestions(category, top_k=3):
    query_embedding = np.array(embedding_model.encode([category]))
    distances, indices = faiss_index.search(query_embedding, top_k)
    suggestions = [{"category": knowledge_base[idx]["category"],
                    "summary": knowledge_base[idx]["summary"],
                    "key_points": knowledge_base[idx]["key_points"]}
                   for idx in indices[0]]
    return suggestions

# Define RAG Pipeline
def rag_response(user_query, spending_category):
    # Retrieve relevant suggestions
    suggestions = retrieve_suggestions(spending_category, top_k=1)
    retrieved_text = f"Category: {suggestions[0]['category']}\nSummary: {suggestions[0]['summary']}\nKey Points: {'; '.join(suggestions[0]['key_points'])}"
    
    # Combine user query with retrieved knowledge
    prompt = (
        f"User query: {user_query}\n"
        f"Retrieved information:\n{retrieved_text}\n"
        f"Provide personalized advice based on the user's query and the retrieved information."
    )
    
    # Generate response
    response = llama_pipe(prompt, max_length=200, num_return_sequences=1)
    return response[0]["generated_text"]

# Example Usage
user_query = "I'm overspending on dining out. What can I do?"
spending_category = "Dining Out"

response = rag_response(user_query, spending_category)
print(response)
